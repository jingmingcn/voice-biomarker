# %%
import pandas as pd
import numpy as np

# %%
feature_names=['F0','VUV','NAQ','QOQ','H1H2','PSP','MDQ','peakSlope','Rd', 
    'Rd_conf','creak','MCEP_0','MCEP_1','MCEP_2','MCEP_3','MCEP_4','MCEP_5', 
    'MCEP_6','MCEP_7','MCEP_8','MCEP_9','MCEP_10','MCEP_11','MCEP_12', 
    'MCEP_13','MCEP_14','MCEP_15','MCEP_16','MCEP_17','MCEP_18', 
    'MCEP_19','MCEP_20','MCEP_21','MCEP_22','MCEP_23','MCEP_24',
    'HMPDM_0','HMPDM_1','HMPDM_2','HMPDM_3','HMPDM_4','HMPDM_5', 
    'HMPDM_6','HMPDM_7','HMPDM_8','HMPDM_9','HMPDM_10','HMPDM_11','HMPDM_12', 
    'HMPDM_13','HMPDM_14','HMPDM_15','HMPDM_16','HMPDM_17','HMPDM_18', 
    'HMPDM_19','HMPDM_20','HMPDM_21','HMPDM_22','HMPDM_23','HMPDM_24',
    'HMPDD_0','HMPDD_1','HMPDD_2','HMPDD_3','HMPDD_4','HMPDD_5', 
    'HMPDD_6','HMPDD_7','HMPDD_8','HMPDD_9','HMPDD_10','HMPDD_11','HMPDD_12'];

stat_feature_names = list(map(lambda n : [f'{n}_mean',f'{n}_std',f'{n}_min',f'{n}_25',f'{n}_50',f'{n}_75',f'{n}_max'], feature_names))
M,N = np.shape(stat_feature_names)
stat_feature_names = np.reshape(stat_feature_names,(M*N))
# Out:
# array(['F0_mean', 'F0_std', 'F0_min', 'F0_25', 'F0_50', 'F0_75', 'F0_max',
#        'VUV_mean', 'VUV_std', 'VUV_min', 'VUV_25', 'VUV_50', 'VUV_75',
#        'VUV_max', 'NAQ_mean', 'NAQ_std', 'NAQ_min', 'NAQ_25', 'NAQ_50',
#        'NAQ_75', 'NAQ_max', 'QOQ_mean', 'QOQ_std', 'QOQ_min', 'QOQ_25',
#        'QOQ_50', 'QOQ_75', 'QOQ_max', 'H1H2_mean', 'H1H2_std', 'H1H2_min',
#        'H1H2_25', 'H1H2_50', 'H1H2_75', 'H1H2_max', 'PSP_mean', 'PSP_std',
#        'PSP_min', 'PSP_25', 'PSP_50', 'PSP_75', 'PSP_max', 'MDQ_mean',
#        'MDQ_std', 'MDQ_min', 'MDQ_25', 'MDQ_50', 'MDQ_75', 'MDQ_max',
#        'peakSlope_mean', 'peakSlope_std', 'peakSlope_min', 'peakSlope_25',
#        'peakSlope_50', 'peakSlope_75', 'peakSlope_max', 'Rd_mean',
#        'Rd_std', 'Rd_min', 'Rd_25', 'Rd_50', 'Rd_75', 'Rd_max',
#        'Rd_conf_mean', 'Rd_conf_std', 'Rd_conf_min', 'Rd_conf_25',
#        'Rd_conf_50', 'Rd_conf_75', 'Rd_conf_max', 'creak_mean',
#        'creak_std', 'creak_min', 'creak_25', 'creak_50', 'creak_75',
#        'creak_max', 'MCEP_0_mean', 'MCEP_0_std', 'MCEP_0_min',
#        'MCEP_0_25', 'MCEP_0_50', 'MCEP_0_75', 'MCEP_0_max', 'MCEP_1_mean',
#        'MCEP_1_std', 'MCEP_1_min', 'MCEP_1_25', 'MCEP_1_50', 'MCEP_1_75',
#        'MCEP_1_max', 'MCEP_2_mean', 'MCEP_2_std', 'MCEP_2_min',
#        'MCEP_23_mean', 'MCEP_23_std', 'MCEP_23_min', 'MCEP_23_25',
#        'MCEP_23_50', 'MCEP_23_75', 'MCEP_23_max', 'MCEP_24_mean',
#        'MCEP_24_std', 'MCEP_24_min', 'MCEP_24_25', 'MCEP_24_50',
#        'MCEP_24_75', 'MCEP_24_max', 'HMPDM_0_mean', 'HMPDM_0_std',
#        'HMPDM_0_min', 'HMPDM_0_25', 'HMPDM_0_50', 'HMPDM_0_75',
#        'HMPDM_0_max', 'HMPDM_1_mean', 'HMPDM_1_std', 'HMPDM_1_min',
#        'HMPDM_1_25', 'HMPDM_1_50', 'HMPDM_1_75', 'HMPDM_1_max',
#        'HMPDM_2_mean', 'HMPDM_2_std', 'HMPDM_2_min', 'HMPDM_2_25',
#        'HMPDM_2_50', 'HMPDM_2_75', 'HMPDM_2_max', 'HMPDM_3_mean',
#        'HMPDM_3_std', 'HMPDM_3_min', 'HMPDM_3_25', 'HMPDM_3_50',
#        'HMPDM_3_75', 'HMPDM_3_max', 'HMPDM_4_mean', 'HMPDM_4_std',
#        'HMPDM_4_min', 'HMPDM_4_25', 'HMPDM_4_50', 'HMPDM_4_75',
#        'HMPDM_4_max', 'HMPDM_5_mean', 'HMPDM_5_std', 'HMPDM_5_min',
#        'HMPDM_5_25', 'HMPDM_5_50', 'HMPDM_5_75', 'HMPDM_5_max',
#        'HMPDM_6_mean', 'HMPDM_6_std', 'HMPDM_6_min', 'HMPDM_6_25',
#        'HMPDM_6_50', 'HMPDM_6_75', 'HMPDM_6_max', 'HMPDM_7_mean',
#        'HMPDM_7_std', 'HMPDM_7_min', 'HMPDM_7_25', 'HMPDM_7_50',
#        'HMPDM_7_75', 'HMPDM_7_max', 'HMPDM_8_mean', 'HMPDM_8_std',
#        'HMPDM_8_min', 'HMPDM_8_25', 'HMPDM_8_50', 'HMPDM_8_75',
#        'HMPDM_8_max', 'HMPDM_9_mean', 'HMPDM_9_std', 'HMPDM_9_min',
#        'HMPDM_9_25', 'HMPDM_9_50', 'HMPDM_9_75', 'HMPDM_9_max',
#        'HMPDM_10_mean', 'HMPDM_10_std', 'HMPDM_10_min', 'HMPDM_10_25',
#        'HMPDM_10_50', 'HMPDM_10_75', 'HMPDM_10_max', 'HMPDM_11_mean',
#        'HMPDM_11_std', 'HMPDM_11_min', 'HMPDM_11_25', 'HMPDM_11_50',
#        'HMPDM_11_75', 'HMPDM_11_max', 'HMPDM_12_mean', 'HMPDM_12_std',
#        'HMPDM_12_min', 'HMPDM_12_25', 'HMPDM_12_50', 'HMPDM_12_75',
#        'HMPDM_12_max', 'HMPDM_13_mean', 'HMPDM_13_std', 'HMPDM_13_min',
#        'HMPDM_13_25', 'HMPDM_13_50', 'HMPDM_13_75', 'HMPDM_13_max',
#        'HMPDM_14_mean', 'HMPDM_14_std', 'HMPDM_14_min', 'HMPDM_14_25',
#        'HMPDM_14_50', 'HMPDM_14_75', 'HMPDM_14_max', 'HMPDM_15_mean',
#        'HMPDM_15_std', 'HMPDM_15_min', 'HMPDM_15_25', 'HMPDM_15_50',
#        'HMPDM_15_75', 'HMPDM_15_max', 'HMPDM_16_mean', 'HMPDM_16_std',
#        'HMPDM_16_min', 'HMPDM_16_25', 'HMPDM_16_50', 'HMPDM_16_75',
#        'HMPDM_16_max', 'HMPDM_17_mean', 'HMPDM_17_std', 'HMPDM_17_min',
#        'HMPDM_17_25', 'HMPDM_17_50', 'HMPDM_17_75', 'HMPDM_17_max',
#        'HMPDM_18_mean', 'HMPDM_18_std', 'HMPDM_18_min', 'HMPDM_18_25',
#        'HMPDM_18_50', 'HMPDM_18_75', 'HMPDM_18_max', 'HMPDM_19_mean',
#        'HMPDM_19_std', 'HMPDM_19_min', 'HMPDM_19_25', 'HMPDM_19_50',
#        'HMPDM_19_75', 'HMPDM_19_max', 'HMPDM_20_mean', 'HMPDM_20_std',
#        'HMPDM_20_min', 'HMPDM_20_25', 'HMPDM_20_50', 'HMPDM_20_75',
#        'HMPDM_20_max', 'HMPDM_21_mean', 'HMPDM_21_std', 'HMPDM_21_min',
#        'HMPDM_21_25', 'HMPDM_21_50', 'HMPDM_21_75', 'HMPDM_21_max',
#        'HMPDM_22_mean', 'HMPDM_22_std', 'HMPDM_22_min', 'HMPDM_22_25',
#        'HMPDM_22_50', 'HMPDM_22_75', 'HMPDM_22_max', 'HMPDM_23_mean',
#        'HMPDM_23_std', 'HMPDM_23_min', 'HMPDM_23_25', 'HMPDM_23_50',
#        'HMPDM_23_75', 'HMPDM_23_max', 'HMPDM_24_mean', 'HMPDM_24_std',
#        'HMPDM_24_min', 'HMPDM_24_25', 'HMPDM_24_50', 'HMPDM_24_75',
#        'HMPDM_24_max', 'HMPDD_0_mean', 'HMPDD_0_std', 'HMPDD_0_min',
#        'HMPDD_0_25', 'HMPDD_0_50', 'HMPDD_0_75', 'HMPDD_0_max',
#        'HMPDD_1_mean', 'HMPDD_1_std', 'HMPDD_1_min', 'HMPDD_1_25',
#        'HMPDD_1_50', 'HMPDD_1_75', 'HMPDD_1_max', 'HMPDD_2_mean',
#        'HMPDD_2_std', 'HMPDD_2_min', 'HMPDD_2_25', 'HMPDD_2_50',
#        'HMPDD_2_75', 'HMPDD_2_max', 'HMPDD_3_mean', 'HMPDD_3_std',
#        'HMPDD_3_min', 'HMPDD_3_25', 'HMPDD_3_50', 'HMPDD_3_75',
#        'HMPDD_3_max', 'HMPDD_4_mean', 'HMPDD_4_std', 'HMPDD_4_min',
#        'HMPDD_4_25', 'HMPDD_4_50', 'HMPDD_4_75', 'HMPDD_4_max',
#        'HMPDD_5_mean', 'HMPDD_5_std', 'HMPDD_5_min', 'HMPDD_5_25',
#        'HMPDD_5_50', 'HMPDD_5_75', 'HMPDD_5_max', 'HMPDD_6_mean',
#        'HMPDD_6_std', 'HMPDD_6_min', 'HMPDD_6_25', 'HMPDD_6_50',
#        'HMPDD_6_75', 'HMPDD_6_max', 'HMPDD_7_mean', 'HMPDD_7_std',
#        'HMPDD_7_min', 'HMPDD_7_25', 'HMPDD_7_50', 'HMPDD_7_75',
#        'HMPDD_7_max', 'HMPDD_8_mean', 'HMPDD_8_std', 'HMPDD_8_min',
#        'HMPDD_8_25', 'HMPDD_8_50', 'HMPDD_8_75', 'HMPDD_8_max',
#        'HMPDD_9_mean', 'HMPDD_9_std', 'HMPDD_9_min', 'HMPDD_9_25',
#        'HMPDD_9_50', 'HMPDD_9_75', 'HMPDD_9_max', 'HMPDD_10_mean',
#        'HMPDD_10_std', 'HMPDD_10_min', 'HMPDD_10_25', 'HMPDD_10_50',
#        'HMPDD_10_75', 'HMPDD_10_max', 'HMPDD_11_mean', 'HMPDD_11_std',
#        'HMPDD_11_min', 'HMPDD_11_25', 'HMPDD_11_50', 'HMPDD_11_75',
#        'HMPDD_11_max', 'HMPDD_12_mean', 'HMPDD_12_std', 'HMPDD_12_min',
#        'HMPDD_12_25', 'HMPDD_12_50', 'HMPDD_12_75', 'HMPDD_12_max'],
#       dtype='<U14')

# %%
# 将时序数据聚集到一组统计变量，mean, ...


y_train_df = pd.read_csv('/Users/jingming/DataSets/COVAREP/y_Train.tsv',sep='\t',header=None, names=['id','label'])
y_train = y_train_df.iloc[:,1]

y_test_df = pd.read_csv('/Users/jingming/DataSets/COVAREP/y_Test.tsv',sep='\t',header=None, names=['id','label'])
y_test = y_test_df.iloc[:,1]

y_df = pd.concat([y_train_df, y_test_df])

# %%
y_df.iloc[:,1]
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 42    0
# 43    0
# 44    0
# 45    0
# 46    0
# Name: label, Length: 154, dtype: int64

# %%
row_list = []

for id in y_df['id']:
    df = pd.read_csv((f'/Users/jingming/DataSets/COVAREP/{id}_COVAREP.csv'),sep=',',header=None, names=feature_names)
    df = df[df['VUV']==1]
    a = df.describe().iloc[1:].to_numpy()
    row_list.append(np.reshape(a,(a.size),order='F'))
    
X_df = pd.DataFrame(data = row_list, columns=stat_feature_names)

# %%
X_y_df = X_df.assign(label=y_df['label'].to_numpy())

# %%
X_y_df.head()
# Out:
#       F0_mean     F0_std  F0_min  F0_25  F0_50  F0_75  F0_max  VUV_mean  \
# 0  199.187302  43.504720    93.0  173.0  189.0  212.0   386.0       1.0
# 1  218.017081  48.128494   100.0  187.5  205.0  242.0   416.0       1.0
# 2  126.224182  39.950262    58.0  103.0  114.0  135.5   254.0       1.0
# 3   90.751698  23.661682    50.0   76.0   84.0   96.5   174.0       1.0
# 4  118.682533  40.009358    50.0   88.5  105.5  138.5   226.0       1.0
#
#    VUV_std  VUV_min  ...  HMPDD_11_75  HMPDD_11_max  HMPDD_12_mean  \
# 0      0.0      1.0  ...     0.124040       0.77371       0.081089
# 1      0.0      1.0  ...     0.195580       0.71642       0.127041
# 2      0.0      1.0  ...    -0.202420       0.61953      -0.182274
# 3      0.0      1.0  ...    -0.288077       0.46514      -0.216009
# 4      0.0      1.0  ...    -0.221880       0.55367      -0.185922
#
#    HMPDD_12_std  HMPDD_12_min  HMPDD_12_25  HMPDD_12_50  HMPDD_12_75  \
# 0      0.161551      -0.49488    -0.015867      0.10117     0.201270
# 1      0.163414      -0.81961     0.040083      0.16172     0.242205
# 2      0.141901      -0.49445    -0.278567     -0.21172    -0.126240
# 3      0.110370      -0.50076    -0.295715     -0.23695    -0.153985
# 4      0.151518      -0.56354    -0.291600     -0.22437    -0.124507
#
#    HMPDD_12_max  label
# 0       0.64151      0
# 1       0.73451      0
# 2       0.68991      0
# 3       0.23156      0
# 4       0.56220      0
#
# [5 rows x 519 columns]

# %%
X_y_df.to_csv('DAIC_stat_features_X_y.csv')

# %%
df = pd.DataFrame({'A':[1,2,3],'B':[4,5,6]})

# a = [[0,1],
#     [2,3],
#     [4,5]]

print(df.describe().iloc[1:])
# Out:
#         A    B
# mean  2.0  5.0
# std   1.0  1.0
# min   1.0  4.0
# 25%   1.5  4.5
# 50%   2.0  5.0
# 75%   2.5  5.5
# max   3.0  6.0
